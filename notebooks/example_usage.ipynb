# %% [markdown]
# # Example usage of my package

# %% [markdown]
# ## Show example images

# %%
from PIL import Image

# %%
img1_path = "C:/Users/koter/Documents/Programy/face-reidentification/face-reidentification/data/lfw-py/lfw_funneled/Adolfo_Rodriguez_Saa/Adolfo_Rodriguez_Saa_0001.jpg"
img2_path = "C:/Users/koter/Documents/Programy/face-reidentification/face-reidentification/data/lfw-py/lfw_funneled/Adolfo_Rodriguez_Saa/Adolfo_Rodriguez_Saa_0002.jpg"

img1 = Image.open(img1_path)
img2 = Image.open(img2_path)

display(img1, img2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>

# %% [markdown]
# ## import package

# %%
import face_reidentification as fr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import face_reidentification as fr
#
# File ~\Documents\Programy\face-reidentification\face-reidentification\face_reidentification\__init__.py:1
# ----> 1 from pretrained import verification
#       2 from fine_tuned import use
#
# ModuleNotFoundError: No module named 'pretrained'

# %% [markdown]
# ## use vector comparing

# %%
encoders = ["densenet", "googlenet", "resnet", "squeezenet", "vgg"]
distance_functions = ["euclidean", "euclidean_l2", "cosine"]

result = fr.verification(
    img1_path = img1_path,
    img2_path = img2_path,
    encoder_name = encoders[1],
    distance_name = distance_functions[2],
    threshold = 0.2
)

print(result)

# %% [markdown]
# ## use fine-tuned models

# %%
architecture = ["densenet", "googlenet", "resnet", "squeezenet", "vgg"]

result = fr.process(
    img1_path = img1_path,
    img2_path = img2_path,
    model_name = architecture[0],
)

print(result)
